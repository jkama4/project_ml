# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import os

# Construct the path to your CSV file relative to this notebook
data_path = os.path.join('..', 'data', 'heart_disease_risk_dataset_earlymed.csv')

# Read the CSV into a pandas DataFrame
df = pd.read_csv(data_path)

# 1) Simple bar chart of Heart_Risk
heart_risk_counts = df['Heart_Risk'].value_counts()

plt.figure(figsize=(6, 4))
plt.bar(heart_risk_counts.index.astype(str),
        heart_risk_counts.values,
        color=['blue', 'red'],
        width=0.6)
plt.xlabel('Heart Risk (0.0 = Low, 1.0 = High)')
plt.ylabel('Count')
plt.title('Distribution of Heart Risk')
plt.show()

# 2) PCA projection of the data
# Drop the target column to isolate features
X = df.drop('Heart_Risk', axis=1)
y = df['Heart_Risk']

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# Path to your dataset
data_path = os.path.join('..', 'data', 'heart_disease_risk_dataset_earlymed.csv')

# Read the CSV into a DataFrame
df = pd.read_csv(data_path)

# Plot histograms of all columns
df.hist(figsize=(12, 10))  # Adjust figsize as needed
plt.tight_layout()         # Prevent labels from overlapping
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# Replace with the correct path to your dataset
data_path = os.path.join('..', 'data', 'heart_disease_risk_dataset_earlymed.csv')

# Load your data
df = pd.read_csv(data_path)

# Count how many times each gender appears
gender_counts = df['Gender'].value_counts()

# Create a bar chart
plt.figure(figsize=(6, 4))
plt.bar(gender_counts.index.astype(str), gender_counts.values, color=['purple', 'green'], width=0.6)

# Customize the plot
plt.xlabel('Gender (0, 1)')  # Adjust this label if you know what 0 and 1 represent
plt.ylabel('Count')
plt.title('Distribution of Gender')
plt.xticks(rotation=0)

# Display the plot
plt.show()
